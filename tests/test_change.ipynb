# %%
from query_data import get_llm
from langchain.schema.output_parser import StrOutputParser
from langchain.prompts import PromptTemplate
_template = """
<instruct>
Take deep and step by step
你的任务是将"首先", "其次","再者","最后" 将对应的句子提取出来,然后重新组合成一个段落,作为论文的一部份.之后再扩写.1000字
<instruct/>
<Q>:{question}
<A>:
"""
q = """
### 调整航班计划

 在分析雷电天气下民航飞机的飞行风险及预防措施时，航班计划的调整是一个关键环节。为了确保飞行安全，航空公司通常会采取一系列的预防措施来应对可能的风险。其中，调整航班起降时间、变更航班路线、延长飞行间隔、提供灵活的改签和退票政策以及加强机组培训和准备等措施，都是常见的做法。
首先，在制定航班计划时，应根据天气预报和气象条件，尽量避免安排在雷电天气条件下起飞和降落。据一项研究表明，雷电天气是导致航班延误的主要因素之一，因此，尽可能地避免在雷电天气下飞行，可以有效地降低航班延误的风险。
其次，根据飞机的性能和燃油消耗情况，合理规划飞行时间和路线，以确保在发生故障或意外时，有足够的余地和时间进行处理。这一点在我国《民航局关于航班调度管理的规定》中有明确的要求，规定了航班调度应当充分考虑飞机的性能和燃油消耗情况，以保障航班的安全性。
再次，飞机起飞前，应该对飞机进行全面检查和试飞，确保飞机在良好的状态下进行飞行。据一项数据显示，由于在起飞前没有进行充分的检查和试飞，导致飞机在飞行过程中发生故障的情况频发，这无疑增加了航班的风险。
最后，在发生起飞延误时，应该及时向乘客和相关部门通报情况，并采取相应的补救措施。这一点在我国《民航局关于航班服务管理的若干规定》中有明确的要求，规定了航空公司应当建立健全的航班服务管理体系，以提高服务质量。
总的来说，通过及时了解天气状况、避开雷暴区、调整飞行参数等措施，可以降低航班在雷电天气下的飞行风险，确保航班安全。同时，这也符合我国对于航空安全的高度重视和严格要求的法规规定。
"""
prompt = PromptTemplate.from_template(_template)
llm = get_llm('stream')
chain = prompt | llm 
chain.invoke({"question": q})
# Out:
#  首先，在分析雷电天气下民航飞机的飞行风险及预防措施时，航班计划的调整是一个关键环节。为了确保飞行安全，航空公司通常会采取一系列的预防措施来应对可能的风险。调整航班起降时间、变更航班路线、延长飞行间隔、提供灵活的改签和退票政策以及加强机组培训和准备等措施，都是常见的做法。
#
# 其次，根据飞机的性能和燃油消耗情况，合理规划飞行时间和路线，以确保在发生故障或意外时，有足够的余地和时间进行处理。这一点在我国《民航局关于航班调度管理的规定》中有明确的要求，规定了航班调度应当充分考虑飞机的性能和燃油消耗情况，以保障航班的安全性。
#
# 再次，飞机起飞前，应该对飞机进行全面检查和试飞，确保飞机在良好的状态下进行飞行。据一项数据显示，由于在起飞前没有进行充分的检查和试飞，导致飞机在飞行过程中发生故障的情况频发，这无疑增加了航班的风险。
#
# 最后，在发生起飞延误时，应该及时向乘客和相关部门通报情况，并采取相应的补救措施。这一点在我国《民航局关于航班服务管理的若干规定》中有明确的要求，规定了航空公司应当建立健全的航班服务管理体系，以提高服务质量。
#
# 总的来说，通过及时了解天气状况、避开雷暴区、调整飞行参数等措施，可以降低航班在雷电天气下的飞行风险，确保航班安全。同时，这也符合我国对于航空安全的高度重视和严格要求的法规规定。
#
# 此外，对于飞行员和机组人员的培训和选拔也至关重要。他们需要掌握各种复杂的飞行技能和紧急情况处理方法，以便在遇到突发情况时能够迅速做出正确的判断和行动。而定期进行的模拟训练和实际操作经验，则有助于提高他们在实际飞行中的应变能力和心理素质。
#
# 另外，航班计划的制定也需要考虑到旅客的需求和舒适度。例如，对于一些长途航班，可以在适当的时候增加休息时间和食品供应，以保证旅客的健康和安全。同时，对于一些特殊群体，如老年人、儿童和残疾人，还需要提供专门的照顾和帮助，以满足他们的特殊需求。
#
# 最后，对于航班的监控和管理，也需要有一套完善的系统来进行。这套系统可以实时跟踪飞机的位置、速度、高度等信息，并在出现问题时及时通知机组人员和地面工作人员，以便他们能够迅速做出反应。同时，这套系统还可以对飞机的燃油消耗、机载设备运行状态等进行监控，从而为飞行安全和效率提供更有力的保障。
#
# ...
